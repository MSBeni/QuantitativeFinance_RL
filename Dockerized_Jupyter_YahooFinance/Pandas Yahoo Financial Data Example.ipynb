# %% [markdown]
# # Example Data Science Notebook
# ## Yahoo Financial Data analyzed with Pandas

# %%
# Install 'pandas_datareader' Library. https://pandas-datareader.readthedocs.io/en/latest/
# !pip install pandas_datareader
# Out:
# Collecting pandas_datareader
#   Downloading pandas_datareader-0.9.0-py3-none-any.whl (107 kB)
#      |████████████████████████████████| 107 kB 1.3 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.23 in /opt/conda/lib/python3.8/site-packages (from pandas_datareader) (1.1.4)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.8/site-packages (from pandas_datareader) (2.25.0)
# Collecting lxml
#   Downloading lxml-4.6.2-cp38-cp38-manylinux1_x86_64.whl (5.4 MB)
#      |████████████████████████████████| 5.4 MB 6.4 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.8/site-packages (from pandas>=0.23->pandas_datareader) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.8/site-packages (from pandas>=0.23->pandas_datareader) (2020.4)
# Requirement already satisfied: numpy>=1.15.4 in /opt/conda/lib/python3.8/site-packages (from pandas>=0.23->pandas_datareader) (1.19.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas_datareader) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests>=2.19.0->pandas_datareader) (2020.11.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests>=2.19.0->pandas_datareader) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests>=2.19.0->pandas_datareader) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests>=2.19.0->pandas_datareader) (2.10)
# Installing collected packages: lxml, pandas-datareader
# Successfully installed lxml-4.6.2 pandas-datareader-0.9.0

# %%
from pandas_datareader import data
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import pandas as pd

# %%
# Define tickers to get data for. We would like Google, Apple, DJI and S&P500
tickers = ['GOOG', 'AAPL', '^DJI', '^GSPC']

# Read data from 2009 till 2018
start = '2009-01-01'
end = '2018-12-31'

# Pandas DataReader using Yahoo data source
all_tickers = data.DataReader(tickers, 'yahoo', start, end)

# %%
all_tickers
# Out:
# Attributes    Adj Close                                              Close  \
# Symbols            GOOG       AAPL          ^DJI        ^GSPC         GOOG
# Date
# 2009-01-02   160.060059   2.795913   9034.690430   931.799988   160.060059
# 2009-01-05   163.412491   2.913912   8952.889648   927.450012   163.412491
# 2009-01-06   166.406265   2.865849   9015.099609   934.700012   166.406265
# 2009-01-07   160.403763   2.803923   8769.700195   906.650024   160.403763
# 2009-01-08   161.987823   2.855991   8742.459961   909.729980   161.987823
# ...                 ...        ...           ...          ...          ...
# 2018-12-24   976.219971  35.854492  21792.199219  2351.100098   976.219971
# 2018-12-26  1039.459961  38.379425  22878.449219  2467.699951  1039.459961
# 2018-12-27  1043.880005  38.130344  23138.820312  2488.830078  1043.880005
# 2018-12-28  1037.079956  38.149883  23062.400391  2485.739990  1037.079956
# 2018-12-31  1035.609985  38.518612  23327.460938  2506.850098  1035.609985
#
# Attributes                                               High             ...  \
# Symbols          AAPL          ^DJI        ^GSPC         GOOG       AAPL  ...
# Date                                                                      ...
# 2009-01-02   3.241071   9034.690430   931.799988   160.309128   3.251429  ...
# 2009-01-05   3.377857   8952.889648   927.450012   165.001541   3.435000  ...
# 2009-01-06   3.322143   9015.099609   934.700012   169.763687   3.470357  ...
# 2009-01-07   3.250357   8769.700195   906.650024   164.837143   3.303571  ...
# 2009-01-08   3.310714   8742.459961   909.729980   161.987823   3.326786  ...
# ...               ...           ...          ...          ...        ...  ...
# 2018-12-24  36.707500  21792.199219  2351.100098  1003.539978  37.887501  ...
# 2018-12-26  39.292500  22878.449219  2467.699951  1040.000000  39.307499  ...
# 2018-12-27  39.037498  23138.820312  2488.830078  1043.890015  39.192501  ...
# 2018-12-28  39.057499  23062.400391  2485.739990  1055.560059  39.630001  ...
# 2018-12-31  39.435001  23327.460938  2506.850098  1052.699951  39.840000  ...
#
# Attributes           Low                      Open                           \
# Symbols             ^DJI        ^GSPC         GOOG       AAPL          ^DJI
# Date
# 2009-01-02   8760.780273   899.349976   153.723801   3.067143   8772.250000
# 2009-01-05   8892.360352   919.530029   159.900650   3.327500   9027.129883
# 2009-01-06   8940.950195   927.280029   165.868286   3.426786   8954.570312
# 2009-01-07   8719.919922   902.369995   163.546982   3.278929   8996.940430
# 2009-01-08   8651.190430   896.809998   158.545731   3.229643   8769.940430
# ...                  ...          ...          ...        ...           ...
# 2018-12-24  21792.199219  2351.100098   973.900024  37.037498  22317.279297
# 2018-12-26  21712.529297  2346.580078   989.010010  37.075001  21857.730469
# 2018-12-27  22267.419922  2397.939941  1017.150024  38.959999  22629.060547
# 2018-12-28  22981.330078  2472.889893  1049.619995  39.375000  23213.609375
# 2018-12-31  23118.300781  2482.820068  1050.959961  39.632500  23153.939453
#
# Attributes                   Volume
# Symbols           ^GSPC        GOOG          AAPL         ^DJI         ^GSPC
# Date
# 2009-01-02   902.989990   7248000.0  7.460152e+08  213700000.0  4.048270e+09
# 2009-01-05   929.169983   9814500.0  1.181608e+09  233760000.0  5.413910e+09
# 2009-01-06   931.169983  12898500.0  1.289310e+09  215410000.0  5.392620e+09
# 2009-01-07   927.450012   9022600.0  7.530488e+08  266710000.0  4.704940e+09
# 2009-01-08   905.729980   7228300.0  6.735008e+08  226620000.0  4.991550e+09
# ...                 ...         ...           ...          ...           ...
# 2018-12-24  2400.560059   1590300.0  1.486768e+08  308420000.0  2.613930e+09
# 2018-12-26  2363.120117   2373300.0  2.343300e+08  433080000.0  4.233990e+09
# 2018-12-27  2442.500000   2109800.0  2.124684e+08  407940000.0  4.096610e+09
# 2018-12-28  2498.770020   1414800.0  1.691656e+08  336510000.0  3.702620e+09
# 2018-12-31  2498.939941   1493300.0  1.400140e+08  288830000.0  3.442870e+09
#
# [2516 rows x 24 columns]

# %%
# Use just Close values
df = all_tickers['Close']

# %%
df
# Out:
# Symbols            GOOG       AAPL          ^DJI        ^GSPC
# Date
# 2009-01-02   160.060059   3.241071   9034.690430   931.799988
# 2009-01-05   163.412491   3.377857   8952.889648   927.450012
# 2009-01-06   166.406265   3.322143   9015.099609   934.700012
# 2009-01-07   160.403763   3.250357   8769.700195   906.650024
# 2009-01-08   161.987823   3.310714   8742.459961   909.729980
# ...                 ...        ...           ...          ...
# 2018-12-24   976.219971  36.707500  21792.199219  2351.100098
# 2018-12-26  1039.459961  39.292500  22878.449219  2467.699951
# 2018-12-27  1043.880005  39.037498  23138.820312  2488.830078
# 2018-12-28  1037.079956  39.057499  23062.400391  2485.739990
# 2018-12-31  1035.609985  39.435001  23327.460938  2506.850098
#
# [2516 rows x 4 columns]

# %%
fig, axs = plt.subplots(figsize=(16,9))
for ticker in df.columns: 
    ticker_data = df.loc[:,ticker]
    ticker_data = ticker_data / ticker_data.max()
    axs.plot(ticker_data.index, ticker_data, label=ticker)
axs.set_xlabel('Date')
axs.set_ylabel('Normalized closing price ($)')
axs.legend()
axs.grid(True)
plt.show()
